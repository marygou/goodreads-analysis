# %%
import pandas as pd
import numpy as np

print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
# Out:
# Pandas version: 3.0.5
# NumPy version: 2.5.2

# %%
df = pd.read_csv('../data/goodreads_library_export.csv')

# %%
df.head() # maybe separate the title into title and subtitle, and the author into first name and last name
# Out:
#      Book Id                                              Title  \
# 0   55987278  Once Upon a Broken Heart (Once Upon a Broken H...
# 1      29044                                 The Secret History
# 2  146943389                      Saving 6 (Boys of Tommen, #3)
# 3   52511432                    Keeping 13 (Boys of Tommen, #2)
# 4     218042                        All About Love: New Visions
#
#              Author         Author l-f Additional Authors           ISBN  \
# 0  Stephanie Garber  Garber, Stephanie                NaN  ="1250268397"
# 1       Donna Tartt       Tartt, Donna                NaN  ="1400031702"
# 2       Chloe Walsh       Walsh, Chloe                NaN  ="1464216002"
# 3       Chloe Walsh       Walsh, Chloe                NaN            =""
# 4        bell hooks        hooks, bell                NaN  ="0060959479"
#
#              ISBN13  My Rating       Publisher         Binding  ...  \
# 0  ="9781250268396"        4.0  Flatiron Books       Hardcover  ...
# ...

# %%
df.shape # 138 books, 24 columns
# Out:
# (138, 23)

# %%
df.columns # most of them aren't useful, but maybe we can use the 'My Rating' column to see if there is a correlation between the rating and the number of pages, or the year of publication

# Genre would be a good column to have, but it is not present in the data. We could try to scrape the genre from the Goodreads website using the book's title and author, but that would be a more complex task.
# Out:
# Index(['Book Id', 'Title', 'Author', 'Author l-f', 'Additional Authors',
#        'ISBN', 'ISBN13', 'My Rating', 'Publisher', 'Binding',
#        'Number of Pages', 'Year Published', 'Original Publication Year',
#        'Date Read', 'Date Added', 'Bookshelves', 'Bookshelves with positions',
#        'Exclusive Shelf', 'My Review', 'Spoiler', 'Private Notes',
#        'Read Count', 'Owned Copies'],
#       dtype='str')

# %%
import sys

print(sys.executable)
# Out:
# c:\Users\maria\Documents\Programming\experiments\goodreads-analysis\.venv\Scripts\python.exe

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Book Id                     138 non-null    int64
#  1   Title                       138 non-null    str
#  2   Author                      138 non-null    str
#  3   Author l-f                  138 non-null    str
#  4   Additional Authors          48 non-null     str
#  5   ISBN                        138 non-null    str
#  6   ISBN13                      138 non-null    str
#  7   My Rating                   138 non-null    float64
#  8   Publisher                   130 non-null    str
#  9   Binding                     138 non-null    str
#  10  Number of Pages             137 non-null    float64
#  11  Year Published              138 non-null    int64
#  12  Original Publication Year   137 non-null    float64
#  13  Date Read                   45 non-null     str
# ...

# %%
df["Exclusive Shelf"].value_counts() # most of the books are in the "read" shelf, but there are also some in the "to-read", "mangá" and "currently-reading" shelves
# Out:
# Exclusive Shelf
# read                 58
# to-read              57
# mangás               20
# currently-reading     3
# Name: count, dtype: int64

# %%
df["My Rating"].mean() # there are some books with a rating of 0, which means that they were not rated by me, maybe filter them out
# Out:
# np.float64(2.0869565217391304)

# %%
rated_books = df[df["My Rating"] > 0]
rated_books["My Rating"].mean() # the mean rating of the books that I rated is 3.9
# Out:
# np.float64(3.9452054794520546)

# %%
rated_books.groupby("Bookshelves")["My Rating"].mean().sort_values(ascending=False) # books in character development and philosophy shelves have the highest mean rating, while books in the romance shelf have the lowest mean rating
# Out:
# Bookshelves
# character-dev, enemies-do-lovers, found-family, lgbt, reflexivo, romance, sa, sad    5.000000
# character-dev, fantasia                                                              5.000000
# clássico, distopia                                                                   5.000000
# clássico, reflexivo                                                                  5.000000
# distopia, romance                                                                    5.000000
# lgbt, mitologia                                                                      5.000000
# mangás                                                                               5.000000
# reflexivo, romance, portugal                                                         5.000000
# lgbt, reflexivo, romance, sa, sad, smut, fame                                        5.000000
# clássico, reflexivo, sad                                                             4.333333
# ...
